# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
from pandas_datareader import data as wb
MSFT = wb.DataReader('MSFT', data_source='yahoo', start='2000-1-1')
MSFT['simple_return'] = (MSFT['Adj Close'] / MSFT['Adj Close'].shift(1)) - 1
print (MSFT['simple_return'])
# Out:
# Date
# 1999-12-31         NaN
# 2000-01-03   -0.001606
# 2000-01-04   -0.033781
# 2000-01-05    0.010544
# 2000-01-06   -0.033498
#                 ...
# 2022-07-19    0.020767
# 2022-07-20    0.010558
# 2022-07-21    0.009799
# 2022-07-22   -0.016916
# 2022-07-25   -0.005876
# Name: simple_return, Length: 5677, dtype: float64

# %% [markdown]
# Plot the simple returns on a graph.

# %%
import matplotlib.pyplot as plt
MSFT['simple_return'].plot(figsize=(8, 5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Calculate the average daily return.

# %%
avg_d_returns = MSFT['simple_return'].mean()
avg_d_returns
# Out:
# 0.0005305463114979251

# %% [markdown]
# Estimate the average annual return.

# %%
avg_annual_returns =  MSFT['simple_return'].mean() * 250

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print(f"Average Annual Returns: {avg_annual_returns * 100} %")
# Out:
# Average Annual Returns: 13.263657787448127 %
